# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-white')

data = np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  2.,   5.,  56., 134., 277., 277., 171.,  59.,  17.,   2.]),
#  array([-3.69528998, -2.96420053, -2.23311108, -1.50202163, -0.77093218,
#         -0.03984273,  0.69124672,  1.42233617,  2.15342562,  2.88451508,
#          3.61560453]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, density=True, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none')
# Out:
# (array([0.00410347, 0.        , 0.00410347, 0.00820693, 0.00410347,
#         0.00820693, 0.04103465, 0.09848316, 0.09027623, 0.14362128,
#         0.17234553, 0.23389751, 0.37341532, 0.27903562, 0.48420887,
#         0.47189848, 0.3405876 , 0.32417374, 0.30365641, 0.2462079 ,
#         0.15182821, 0.10258663, 0.0820693 , 0.05744851, 0.04103465,
#         0.0123104 , 0.01641386, 0.00410347, 0.        , 0.00410347]),
#  array([-3.69528998, -3.4515935 , -3.20789701, -2.96420053, -2.72050405,
#         -2.47680756, -2.23311108, -1.9894146 , -1.74571811, -1.50202163,
#         -1.25832515, -1.01462866, -0.77093218, -0.5272357 , -0.28353921,
#         -0.03984273,  0.20385376,  0.44755024,  0.69124672,  0.93494321,
#          1.17863969,  1.42233617,  1.66603266,  1.90972914,  2.15342562,
#          2.39712211,  2.64081859,  2.88451508,  3.12821156,  3.37190804,
#          3.61560453]),
#  <a list of 1 Patch objects>)

# %%
# 均值，方差，个数
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
# np.random.normal?
kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.0060898 , 0.0030449 , 0.0030449 , 0.        , 0.02131429,
#         0.0091347 , 0.02740409, 0.02740409, 0.03653878, 0.04262858,
#         0.04567348, 0.05480818, 0.06394287, 0.08830206, 0.13093064,
#         0.15224493, 0.17660412, 0.21618781, 0.20705311, 0.2375021 ,
#         0.19487352, 0.17964902, 0.17355923, 0.14920004, 0.19182862,
#         0.10352656, 0.11875105, 0.09134696, 0.07307757, 0.07916737,
#         0.03653878, 0.03044899, 0.01217959, 0.03349389, 0.01522449,
#         0.        , 0.0091347 , 0.        , 0.        , 0.0030449 ]),
#  array([-3.65883677, -3.33041862, -3.00200047, -2.67358232, -2.34516416,
#         -2.01674601, -1.68832786, -1.35990971, -1.03149156, -0.70307341,
#         -0.37465525, -0.0462371 ,  0.28218105,  0.6105992 ,  0.93901735,
#          1.2674355 ,  1.59585366,  1.92427181,  2.25268996,  2.58110811,
#          2.90952626,  3.23794441,  3.56636256,  3.89478072,  4.22319887,
#          4.55161702,  4.88003517,  5.20845332,  5.53687147,  5.86528963,
#          6.19370778,  6.52212593,  6.85054408,  7.17896223,  7.50738038,
#          7.83579854,  8.16421669,  8.49263484,  8.82105299,  9.14947114,
#          9.47788929]),
#  <a list of 1 Patch objects>)

# %%
counts, bin_edges = np.histogram(data, bins=5)
counts
# Out:
# array([  7, 190, 554, 230,  19])

# %%
bin_edges
# Out:
# array([-3.69528998, -2.23311108, -0.77093218,  0.69124672,  2.15342562,
#         3.61560453])

# %%
# 二维频次直方图
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 1000).T

# %%
# 1. plt.hist2d()
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('Counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
# 2. plt.hexbin()
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %%
# 3. kernel density estimation
from scipy.stats import gaussian_kde

# 拟合数组维度[Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)

#  用一对规则的网格数据进行拟合
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# plot
plt.imshow(Z.reshape(Xgrid.shape),
          origin='lower', aspect='auto',
          extent=[-3.5, 3.5, -6, 6],
          cmap='Blues')
plt.colorbar(label='density')
